# %% [markdown]
# # 单卡GPU 进行 ChatGLM3-6B模型 LORA 高效微调
# 本 Cookbook 将带领开发者使用 `AdvertiseGen` 对 ChatGLM3-6B 数据集进行 lora微调，使其具备专业的广告生成能力。
#
# ## 硬件需求
# 显存：24GB及以上（推荐使用30系或A10等sm80架构以上的NVIDIA显卡进行尝试）
# 内存：16GB
# RAM: 2.9 /16 GB
# GPU RAM: 15.5/16.0 GB

# %% [markdown]
# ## 0. 环境检查
# 首先，先检查代码的运行地址，确保运行地址处于 `finetune_demo` 中。
# 并且，确保已经安装了 `requirements.txt`中的依赖。
#
# > 本 demo 中，不需要使用 deepspeed, mpi4py 两个依赖，如果您安装这两个依赖遇到问题，可以不安装这两个依赖。

# %%
import os

# os.environ['http_proxy'] = ''
# os.environ['https_proxy'] = ''
os.environ['HF_HOME'] = '/root/onethingai-fs/models'
os.environ['HF_HUB_CACHE'] = '/root/onethingai-fs/models/hub'
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'
os.environ['KMP_AFFINITY'] = 'disabled'

# %%
# !pwd
# Out:
# /root/autodl-tmp/ChatGLM3/finetune_demo

# %% [markdown]
# ## 1. 准备数据集
# 我们使用 AdvertiseGen 数据集来进行微调。从 [Google Drive](https://drive.google.com/file/d/13_vf0xRTQsyneRKdD1bZIr93vBGOczrk/view?usp=sharing) 或者 [Tsinghua Cloud](https://cloud.tsinghua.edu.cn/f/b3f119a008264b1cabd1/?dl=1) 下载处理好的 AdvertiseGen 数据集，将解压后的 AdvertiseGen 目录放到本目录的 `/data/` 下, 例如。
# > /media/zr/Data/Code/ChatGLM3/finetune_demo/data/AdvertiseGen

# %%
import json
from typing import Union
from pathlib import Path


def _resolve_path(path: Union[str, Path]) -> Path:
    return Path(path).expanduser().resolve()


def _mkdir(dir_name: Union[str, Path]):
    dir_name = _resolve_path(dir_name)
    if not dir_name.is_dir():
        dir_name.mkdir(parents=True, exist_ok=False)


def convert_adgen(data_dir: Union[str, Path], save_dir: Union[str, Path]):
    def _convert(in_file: Path, out_file: Path):
        _mkdir(out_file.parent)
        with open(in_file, encoding='utf-8') as fin:
            with open(out_file, 'wt', encoding='utf-8') as fout:
                for line in fin:
                    dct = json.loads(line)
                    sample = {'conversations': [{'role': 'user', 'content': dct['content']},
                                                {'role': 'assistant', 'content': dct['summary']}]}
                    fout.write(json.dumps(sample, ensure_ascii=False) + '\n')

    data_dir = _resolve_path(data_dir)
    save_dir = _resolve_path(save_dir)

    train_file = data_dir / 'train.json'
    if train_file.is_file():
        out_file = save_dir / train_file.relative_to(data_dir)
        _convert(train_file, out_file)

    dev_file = data_dir / 'dev.json'
    if dev_file.is_file():
        out_file = save_dir / dev_file.relative_to(data_dir)
        _convert(dev_file, out_file)


convert_adgen('data/AdvertiseGen', 'data/AdvertiseGen_fix')

# %% [markdown]
# ## 2. 使用命令行开始微调,我们使用 lora 进行微调
# 接着，我们仅需要将配置好的参数以命令行的形式传参给程序，就可以使用命令行进行高效微调。

# %%
# !CUDA_VISIBLE_DEVICES=0 NCCL_P2P_DISABLE="1" NCCL_IB_DISABLE="1" python finetune_hf.py  data/AdvertiseGen_fix  THUDM/chatglm3-6b  configs/lora.yaml
# Out:
# 16988.77s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# /root/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Setting eos_token is not supported, use the default one.
# Setting pad_token is not supported, use the default one.
# Setting unk_token is not supported, use the default one.
# Loading checkpoint shards: 100%|██████████████████| 7/7 [00:02<00:00,  2.83it/s]
# trainable params: 1,949,696 || all params: 6,245,533,696 || trainable%: 0.0312
# --> Model
#
# --> model has 1.949696M params
#
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
# Map: 100%|█████████████████████████████████| 1/1 [00:10<00:00, 10.50s/ examples]
# train_dataset: Dataset({
#     features: ['input_ids', 'labels'],
#     num_rows: 1
# })
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
# Map: 100%|█████████████████████████████████| 1/1 [00:00<00:00, 93.42 examples/s]
# val_dataset: Dataset({
#     features: ['input_ids', 'output_ids'],
#     num_rows: 3
# })
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
# Map: 100%|█████████████████████████████████| 1/1 [00:00<00:00, 92.95 examples/s]
# test_dataset: Dataset({
#     features: ['input_ids', 'output_ids'],
#     num_rows: 3
# })
# --> Sanity check
#            '[gMASK]': 64790 -> -100
#                'sop': 64792 -> -100
#           '<|user|>': 64795 -> -100
#                   '': 30910 -> -100
#                 '\n': 13 -> -100
#                   '': 30910 -> -100
#                 '类型': 33467 -> -100
#                  '#': 31010 -> -100
#                  '裤': 56532 -> -100
#                  '*': 30998 -> -100
#                  '版': 55090 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                 '宽松': 40833 -> -100
#                  '*': 30998 -> -100
#                 '风格': 32799 -> -100
#                  '#': 31010 -> -100
#                 '性感': 40589 -> -100
#                  '*': 30998 -> -100
#                 '图案': 37505 -> -100
#                  '#': 31010 -> -100
#                 '线条': 37216 -> -100
#                  '*': 30998 -> -100
#                  '裤': 56532 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                  '阔': 56529 -> -100
#                  '腿': 56158 -> -100
#                  '裤': 56532 -> -100
#      '<|assistant|>': 64796 -> -100
#                   '': 30910 -> 30910
#                 '\n': 13 -> 13
#                   '': 30910 -> 30910
#                 '宽松': 40833 -> 40833
#                  '的': 54530 -> 54530
#                  '阔': 56529 -> 56529
#                  '腿': 56158 -> 56158
#                  '裤': 56532 -> 56532
#                  '这': 54551 -> 54551
#                 '两年': 33808 -> 33808
#                 '真的': 32041 -> 32041
#                  '吸': 55360 -> 55360
#                  '粉': 55486 -> 55486
#                 '不少': 32138 -> 32138
#                  '，': 31123 -> 31123
#                 '明星': 32943 -> 32943
#                 '时尚': 33481 -> 33481
#                  '达': 54880 -> 54880
#                 '人的': 31664 -> 31664
#                 '心头': 46565 -> 46565
#                  '爱': 54799 -> 54799
#                  '。': 31155 -> 31155
#                 '毕竟': 33051 -> 33051
#                  '好': 54591 -> 54591
#                  '穿': 55432 -> 55432
#                 '时尚': 33481 -> 33481
#                  '，': 31123 -> 31123
#                  '谁': 55622 -> 55622
#                 '都能': 32904 -> 32904
#                  '穿': 55432 -> 55432
#                  '出': 54557 -> 54557
#                  '腿': 56158 -> 56158
#                  '长': 54625 -> 54625
#                  '2': 30943 -> 30943
#                  '米': 55055 -> 55055
#                '的效果': 35590 -> 35590
#                 '宽松': 40833 -> 40833
#                  '的': 54530 -> 54530
#                  '裤': 56532 -> 56532
#                  '腿': 56158 -> 56158
#                  '，': 31123 -> 31123
#                '当然是': 48466 -> 48466
#                  '遮': 57148 -> 57148
#                  '肉': 55343 -> 55343
#                  '小': 54603 -> 54603
#                 '能手': 49355 -> 49355
#                  '啊': 55674 -> 55674
#                  '。': 31155 -> 31155
#                 '上身': 51605 -> 51605
#                  '随': 55119 -> 55119
#                  '性': 54642 -> 54642
#                 '自然': 31799 -> 31799
#                  '不': 54535 -> 54535
#                  '拘': 57036 -> 57036
#                  '束': 55625 -> 55625
#                  '，': 31123 -> 31123
#                 '面料': 46839 -> 46839
#                  '亲': 55113 -> 55113
#                  '肤': 56089 -> 56089
#                 '舒适': 33894 -> 33894
#                  '贴': 55778 -> 55778
#                 '身体': 31902 -> 31902
#                  '验': 55017 -> 55017
#                  '感': 54706 -> 54706
#                  '棒': 56382 -> 56382
#                  '棒': 56382 -> 56382
#                  '哒': 59230 -> 59230
#                  '。': 31155 -> 31155
#                  '系': 54712 -> 54712
#                  '带': 54882 -> 54882
#                 '部分': 31726 -> 31726
#                 '增加': 31917 -> 31917
#                 '设计': 31735 -> 31735
#                 '看点': 45032 -> 45032
#                  '，': 31123 -> 31123
#                  '还': 54656 -> 54656
#                  '让': 54772 -> 54772
#                 '单品': 46539 -> 46539
#                '的设计': 34481 -> 34481
#                  '感': 54706 -> 54706
#                 '更强': 43084 -> 43084
#                  '。': 31155 -> 31155
#                 '腿部': 46799 -> 46799
#                 '线条': 37216 -> 37216
#                  '若': 55351 -> 55351
#                  '隐': 55733 -> 55733
#                  '若': 55351 -> 55351
#                  '现': 54600 -> 54600
#                  '的': 54530 -> 54530
#                  '，': 31123 -> 31123
#                 '性感': 40589 -> 40589
#                  '撩': 58521 -> 58521
#                  '人': 54533 -> 54533
#                  '。': 31155 -> 31155
#                 '颜色': 33692 -> 33692
#                  '敲': 57004 -> 57004
#                 '温柔': 34678 -> 34678
#                  '的': 54530 -> 54530
#                  '，': 31123 -> 31123
#                  '与': 54619 -> 54619
#                 '裤子': 44722 -> 44722
#                 '本身': 32754 -> 32754
#                  '所': 54626 -> 54626
#                 '呈现': 33169 -> 33169
#                '的风格': 48084 -> 48084
#                 '有点': 33149 -> 33149
#                  '反': 54955 -> 54955
#                  '差': 55342 -> 55342
#                  '萌': 56842 -> 56842
#                  '。': 31155 -> 31155
#           '<|user|>': 64795 -> 64795
#                   '': 30910 -> -100
#                 '\n': 13 -> -100
#                   '': 30910 -> -100
#                 '类型': 33467 -> -100
#                  '#': 31010 -> -100
#                  '裙': 56778 -> -100
#                  '*': 30998 -> -100
#                 '风格': 32799 -> -100
#                  '#': 31010 -> -100
#                 '简约': 40512 -> -100
#                  '*': 30998 -> -100
#                 '图案': 37505 -> -100
#                  '#': 31010 -> -100
#                  '条': 54907 -> -100
#                  '纹': 56487 -> -100
#                  '*': 30998 -> -100
#                 '图案': 37505 -> -100
#                  '#': 31010 -> -100
#                 '线条': 37216 -> -100
#                  '*': 30998 -> -100
#                 '图案': 37505 -> -100
#                  '#': 31010 -> -100
#                  '撞': 56483 -> -100
#                  '色': 54785 -> -100
#                  '*': 30998 -> -100
#                  '裙': 56778 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                  '鱼': 55530 -> -100
#                  '尾': 55999 -> -100
#                  '裙': 56778 -> -100
#                  '*': 30998 -> -100
#                  '裙': 56778 -> -100
#                  '袖': 56896 -> -100
#                  '长': 54625 -> -100
#                  '#': 31010 -> -100
#                  '无': 54716 -> -100
#                  '袖': 56896 -> -100
#      '<|assistant|>': 64796 -> -100
#                   '': 30910 -> 30910
#                 '\n': 13 -> 13
#                   '': 30910 -> 30910
#                 '圆形': 41379 -> 41379
#                  '领': 54847 -> 54847
#                  '口': 54815 -> 54815
#                 '修饰': 43518 -> 43518
#                  '脖': 57777 -> 57777
#                  '颈': 56682 -> 56682
#                 '线条': 37216 -> 37216
#                  '，': 31123 -> 31123
#                 '适合': 32570 -> 32570
#                 '各种': 31986 -> 31986
#                  '脸': 55747 -> 55747
#                  '型': 54888 -> 54888
#                  '，': 31123 -> 31123
#                  '耐': 56016 -> 56016
#                  '看': 54652 -> 54652
#                  '有': 54536 -> 54536
#                 '气质': 34219 -> 34219
#                  '。': 31155 -> 31155
#                  '无': 54716 -> 54716
#                  '袖': 56896 -> 56896
#                 '设计': 31735 -> 31735
#                  '，': 31123 -> 31123
#                  '尤': 55661 -> 55661
#                  '显': 55101 -> 55101
#                 '清凉': 42983 -> 42983
#                  '，': 31123 -> 31123
#                 '简约': 40512 -> 40512
#                  '横': 56091 -> 56091
#                  '条': 54907 -> 54907
#                  '纹': 56487 -> 56487
#                 '装饰': 34394 -> 34394
#                  '，': 31123 -> 31123
#                 '使得': 33313 -> 33313
#                  '整': 54877 -> 54877
#                  '身': 54715 -> 54715
#                  '人': 54533 -> 54533
#                  '鱼': 55530 -> 55530
#                 '造型': 33561 -> 33561
#                 '更为': 34084 -> 34084
#                 '生动': 34551 -> 34551
#                 '立体': 37509 -> 37509
#                  '。': 31155 -> 31155
#                 '加之': 43011 -> 43011
#                  '撞': 56483 -> 56483
#                 '色的': 32492 -> 32492
#                  '鱼': 55530 -> 55530
#                  '尾': 55999 -> 55999
#                  '下': 54578 -> 54578
#                  '摆': 56164 -> 56164
#                  '，': 31123 -> 31123
#                 '深邃': 52198 -> 52198
#                 '富有': 35021 -> 35021
#                 '诗意': 47616 -> 47616
#                  '。': 31155 -> 31155
#                  '收': 54821 -> 54821
#                  '腰': 56278 -> 56278
#                  '包': 54947 -> 54947
#                  '臀': 58276 -> 58276
#                  ',': 30932 -> 30932
#                 '修饰': 43518 -> 43518
#                 '女性': 32291 -> 32291
#                 '身体': 31902 -> 31902
#                 '曲线': 38871 -> 38871
#                  '，': 31123 -> 31123
#                 '结合': 31975 -> 31975
#                  '别': 54835 -> 54835
#                  '出': 54557 -> 54557
#                  '心': 54581 -> 54581
#                  '裁': 55857 -> 55857
#                  '的': 54530 -> 54530
#                  '鱼': 55530 -> 55530
#                  '尾': 55999 -> 55999
#                  '裙': 56778 -> 56778
#                  '摆': 56164 -> 56164
#                 '设计': 31735 -> 31735
#                  '，': 31123 -> 31123
#                 '勾勒': 45588 -> 45588
#                  '出': 54557 -> 54557
#                 '自然': 31799 -> 31799
#                 '流畅': 40315 -> 40315
#                '的身体': 42357 -> 42357
#                 '轮廓': 48233 -> 48233
#                  '，': 31123 -> 31123
#                '展现了': 38612 -> 38612
#                  '婀': 60165 -> 60165
#                  '娜': 56438 -> 56438
#                 '多姿': 49074 -> 49074
#                  '的': 54530 -> 54530
#                 '迷人': 43691 -> 43691
#                 '姿态': 36975 -> 36975
#                  '。': 31155 -> 31155
#           '<|user|>': 64795 -> 64795
#                   '': 30910 -> -100
#                 '\n': 13 -> -100
#                   '': 30910 -> -100
#                 '类型': 33467 -> -100
#                  '#': 31010 -> -100
#                 '上衣': 49534 -> -100
#                  '*': 30998 -> -100
#                  '版': 55090 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                 '宽松': 40833 -> -100
#                  '*': 30998 -> -100
#                 '颜色': 33692 -> -100
#                  '#': 31010 -> -100
#                  '粉': 55486 -> -100
#                 '红色': 32632 -> -100
#                  '*': 30998 -> -100
#                 '图案': 37505 -> -100
#                  '#': 31010 -> -100
#                 '字母': 41260 -> -100
#                  '*': 30998 -> -100
#                 '图案': 37505 -> -100
#                  '#': 31010 -> -100
#                 '文字': 32502 -> -100
#                  '*': 30998 -> -100
#                 '图案': 37505 -> -100
#                  '#': 31010 -> -100
#                 '线条': 37216 -> -100
#                  '*': 30998 -> -100
#                  '衣': 55500 -> -100
#                 '样式': 46025 -> -100
#                  '#': 31010 -> -100
#                  '卫': 55233 -> -100
#                  '衣': 55500 -> -100
#                  '*': 30998 -> -100
#                  '衣': 55500 -> -100
#                 '款式': 40877 -> -100
#                  '#': 31010 -> -100
#                  '不': 54535 -> -100
#                 '规则': 33257 -> -100
#      '<|assistant|>': 64796 -> -100
#                   '': 30910 -> 30910
#                 '\n': 13 -> 13
#                   '': 30910 -> 30910
#                 '宽松': 40833 -> 40833
#                  '的': 54530 -> 54530
#                  '卫': 55233 -> 55233
#                  '衣': 55500 -> 55500
#                  '版': 55090 -> 55090
#                  '型': 54888 -> 54888
#                 '包裹': 39050 -> 39050
#                  '着': 54666 -> 54666
#                 '整个': 32307 -> 32307
#                 '身材': 34319 -> 34319
#                  '，': 31123 -> 31123
#                  '宽': 55825 -> 55825
#                 '大的': 31706 -> 31706
#                  '衣': 55500 -> 55500
#                  '身': 54715 -> 54715
#                  '与': 54619 -> 54619
#                 '身材': 34319 -> 34319
#                 '形成': 31918 -> 31918
#                '鲜明的': 43808 -> 43808
#                 '对比': 34193 -> 34193
#                 '描绘': 38102 -> 38102
#                  '出': 54557 -> 54557
#                  '纤': 56686 -> 56686
#                  '瘦': 56726 -> 56726
#                 '的身': 36209 -> 36209
#                  '形': 54874 -> 54874
#                  '。': 31155 -> 31155
#                  '下': 54578 -> 54578
#                  '摆': 56164 -> 56164
#                  '与': 54619 -> 54619
#                  '袖': 56896 -> 56896
#                  '口': 54815 -> 54815
#                 '的不': 33069 -> 33069
#                 '规则': 33257 -> 33257
#                  '剪': 56597 -> 56597
#                  '裁': 55857 -> 55857
#                 '设计': 31735 -> 31735
#                  '，': 31123 -> 31123
#                 '彰显': 35765 -> 35765
#                  '出': 54557 -> 54557
#                 '时尚': 33481 -> 33481
#                  '前': 54624 -> 54624
#                  '卫': 55233 -> 55233
#                  '的': 54530 -> 54530
#                 '形态': 34178 -> 34178
#                  '。': 31155 -> 31155
#                  '被': 54732 -> 54732
#                  '剪': 56597 -> 56597
#                  '裁': 55857 -> 55857
#                 '过的': 33258 -> 33258
#                 '样式': 46025 -> 46025
#                '呈现出': 39080 -> 39080
#                  '布': 54901 -> 54901
#                  '条': 54907 -> 54907
#                  '状': 55191 -> 55191
#                 '自然': 31799 -> 31799
#                  '地': 54563 -> 54563
#                  '垂': 56716 -> 56716
#                  '坠': 57486 -> 57486
#                 '下来': 32246 -> 32246
#                  '，': 31123 -> 31123
#                  '别': 54835 -> 54835
#                  '具': 54893 -> 54893
#                 '有一': 31741 -> 31741
#                  '番': 56331 -> 56331
#                 '设计': 31735 -> 31735
#                  '感': 54706 -> 54706
#                  '。': 31155 -> 31155
#                 '线条': 37216 -> 37216
#                  '分': 54584 -> 54584
#                 '明的': 33882 -> 33882
#                 '字母': 41260 -> 41260
#                 '样式': 46025 -> 46025
#                 '有着': 32613 -> 32613
#                  '花': 54867 -> 54867
#                 '式的': 34172 -> 34172
#                 '外观': 35062 -> 35062
#                  '，': 31123 -> 31123
#                  '棱': 58368 -> 58368
#                  '角': 55133 -> 55133
#                 '分明': 41256 -> 41256
#                 '加上': 32755 -> 32755
#                 '具有': 31817 -> 31817
#                 '少女': 34574 -> 34574
#                  '元': 54751 -> 54751
#                 '气的': 34667 -> 34667
#                  '枣': 57213 -> 57213
#                 '红色': 32632 -> 32632
#                 '十分': 32177 -> 32177
#                  '有': 54536 -> 54536
#                 '年轻': 32237 -> 32237
#                 '活力': 33870 -> 33870
#                  '感': 54706 -> 54706
#                  '。': 31155 -> 31155
#                  '粉': 55486 -> 55486
#                '红色的': 42290 -> 42290
#                  '衣': 55500 -> 55500
#                  '身': 54715 -> 54715
#                  '把': 54849 -> 54849
#                 '肌肤': 40398 -> 40398
#                 '衬托': 50927 -> 50927
#                 '得很': 35013 -> 35013
#                  '白': 54902 -> 54902
#                  '嫩': 56944 -> 56944
#                  '又': 54892 -> 54892
#                 '健康': 31740 -> 31740
#                  '。': 31155 -> 31155
#           '<|user|>': 64795 -> 64795
#                   '': 30910 -> -100
#                 '\n': 13 -> -100
#                   '': 30910 -> -100
#                 '类型': 33467 -> -100
#                  '#': 31010 -> -100
#                  '裙': 56778 -> -100
#                  '*': 30998 -> -100
#                  '版': 55090 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                 '宽松': 40833 -> -100
#                  '*': 30998 -> -100
#                 '材质': 38317 -> -100
#                  '#': 31010 -> -100
#                  '雪': 55534 -> -100
#                  '纺': 57375 -> -100
#                  '*': 30998 -> -100
#                 '风格': 32799 -> -100
#                  '#': 31010 -> -100
#                 '清新': 37785 -> -100
#                  '*': 30998 -> -100
#                  '裙': 56778 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                  'a': 30913 -> -100
#                  '字': 54952 -> -100
#                  '*': 30998 -> -100
#                  '裙': 56778 -> -100
#                  '长': 54625 -> -100
#                  '#': 31010 -> -100
#                '连衣裙': 44724 -> -100
#      '<|assistant|>': 64796 -> -100
#                   '': 30910 -> 30910
#                 '\n': 13 -> 13
#                   '': 30910 -> 30910
#                  '踩': 57380 -> 57380
#                  '着': 54666 -> 54666
#                 '轻盈': 52124 -> 52124
#                '的步伐': 52737 -> 52737
#                 '享受': 32600 -> 32600
#                  '在': 54534 -> 54534
#                  '午': 55357 -> 55357
#                 '后的': 32313 -> 32313
#                  '和': 54542 -> 54542
#                  '煦': 59353 -> 59353
#                  '风': 54803 -> 54803
#                  '中': 54538 -> 54538
#                  '，': 31123 -> 31123
#                  '让': 54772 -> 54772
#                 '放松': 34794 -> 34794
#                  '与': 54619 -> 54619
#                 '惬意': 49423 -> 49423
#                  '感': 54706 -> 54706
#                 '为你': 36280 -> 36280
#                 '免去': 48449 -> 48449
#                  '一': 54531 -> 54531
#                 '身的': 35879 -> 35879
#                 '压力': 32507 -> 32507
#                  '与': 54619 -> 54619
#                 '束缚': 42426 -> 42426
#                  '，': 31123 -> 31123
#                 '仿佛': 34628 -> 34628
#                 '要将': 45901 -> 45901
#                 '灵魂': 34617 -> 34617
#                  '也': 54574 -> 54574
#                 '寄托': 43278 -> 43278
#                  '在': 54534 -> 54534
#                 '随风': 54377 -> 54377
#                  '摇': 56401 -> 56401
#                  '曳': 59138 -> 59138
#                  '的': 54530 -> 54530
#                  '雪': 55534 -> 55534
#                  '纺': 57375 -> 57375
#                '连衣裙': 44724 -> 44724
#                  '上': 54547 -> 54547
#                  '，': 31123 -> 31123
#                  '吐': 56457 -> 56457
#                 '露出': 38142 -> 38142
#                  '<': 31002 -> 31002
#                 'UN': 5234 -> 5234
#                  'K': 30984 -> 30984
#                  '>': 30994 -> 30994
#                 '微妙': 53460 -> 53460
#                 '而又': 37880 -> 37880
#                 '浪漫': 34317 -> 34317
#                  '的': 54530 -> 54530
#                 '清新': 37785 -> 37785
#                 '之意': 39194 -> 39194
#                  '。': 31155 -> 31155
#                 '宽松': 40833 -> 40833
#                  '的': 54530 -> 54530
#                  'a': 30913 -> 30913
#                  '字': 54952 -> 54952
#                  '版': 55090 -> 55090
#                  '型': 54888 -> 54888
#                 '除了': 31992 -> 31992
#                 '能够': 31759 -> 31759
#                 '带来': 32286 -> 32286
#                '足够的': 37688 -> 37688
#                 '空间': 32042 -> 32042
#                  '，': 31123 -> 31123
#                 '也能': 33073 -> 33073
#                 '以上': 31840 -> 31840
#                  '窄': 57366 -> 57366
#                  '下': 54578 -> 54578
#                  '宽': 55825 -> 55825
#                '的方式': 32552 -> 32552
#                 '强化': 32612 -> 32612
#                 '立体': 37509 -> 37509
#                 '层次': 33612 -> 33612
#                  '，': 31123 -> 31123
#                 '携带': 35914 -> 35914
#                  '出': 54557 -> 54557
#                 '自然': 31799 -> 31799
#                 '优雅': 35752 -> 35752
#                  '的': 54530 -> 54530
#                  '曼': 56115 -> 56115
#                  '妙': 56150 -> 56150
#                 '体验': 32300 -> 32300
#                  '。': 31155 -> 31155
#           '<|user|>': 64795 -> 64795
#                   '': 30910 -> -100
#                 '\n': 13 -> -100
#                   '': 30910 -> -100
#                 '类型': 33467 -> -100
#                  '#': 31010 -> -100
#                 '上衣': 49534 -> -100
#                  '*': 30998 -> -100
#                 '材质': 38317 -> -100
#                  '#': 31010 -> -100
#                  '棉': 57007 -> -100
#                  '*': 30998 -> -100
#                 '颜色': 33692 -> -100
#                  '#': 31010 -> -100
#                 '蓝色': 35798 -> -100
#                  '*': 30998 -> -100
#                 '风格': 32799 -> -100
#                  '#': 31010 -> -100
#                  '潮': 55755 -> -100
#                  '*': 30998 -> -100
#                  '衣': 55500 -> -100
#                 '样式': 46025 -> -100
#                  '#': 31010 -> -100
#                  'p': 30925 -> -100
#                'olo': 9795 -> -100
#                  '*': 30998 -> -100
#                  '衣': 55500 -> -100
#                  '领': 54847 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                  'p': 30925 -> -100
#                'olo': 9795 -> -100
#                  '领': 54847 -> -100
#                  '*': 30998 -> -100
#                  '衣': 55500 -> -100
#                  '袖': 56896 -> -100
#                  '长': 54625 -> -100
#                  '#': 31010 -> -100
#                  '短': 55354 -> -100
#                  '袖': 56896 -> -100
#                  '*': 30998 -> -100
#                  '衣': 55500 -> -100
#                 '款式': 40877 -> -100
#                  '#': 31010 -> -100
#                  '拼': 56069 -> -100
#                  '接': 54762 -> -100
#      '<|assistant|>': 64796 -> -100
#                   '': 30910 -> 30910
#                 '\n': 13 -> 13
#                   '': 30910 -> 30910
#                 '想要': 32212 -> 32212
#                  '在': 54534 -> 54534
#                '人群中': 52744 -> 52744
#               '脱颖而出': 44933 -> 44933
#                  '吗': 55398 -> 55398
#                  '？': 31514 -> 31514
#                 '那么': 31783 -> 31783
#                '最适合': 46827 -> 46827
#                 '您的': 33379 -> 33379
#                '莫过于': 48269 -> 48269
#                 '这款': 33730 -> 33730
#                  'p': 30925 -> 30925
#                'olo': 9795 -> 9795
#                  '衫': 57439 -> 57439
#                  '短': 55354 -> 55354
#                  '袖': 56896 -> 56896
#                  '，': 31123 -> 31123
#                '采用了': 36480 -> 36480
#                '经典的': 42733 -> 42733
#                  'p': 30925 -> 30925
#                'olo': 9795 -> 9795
#                  '领': 54847 -> 54847
#                  '口': 54815 -> 54815
#                  '和': 54542 -> 54542
#                 '柔软': 39819 -> 39819
#                  '纯': 55906 -> 55906
#                  '棉': 57007 -> 57007
#                 '面料': 46839 -> 46839
#                  '，': 31123 -> 31123
#                 '让您': 52700 -> 52700
#                 '紧跟': 48513 -> 48513
#                 '时尚': 33481 -> 33481
#                 '潮流': 36600 -> 36600
#                  '。': 31155 -> 31155
#                  '再': 54860 -> 54860
#                 '配合': 32617 -> 32617
#                  '上': 54547 -> 54547
#                 '潮流': 36600 -> 36600
#                  '的': 54530 -> 54530
#                 '蓝色': 35798 -> 35798
#                  '拼': 56069 -> 56069
#                  '接': 54762 -> 54762
#                 '设计': 31735 -> 31735
#                  '，': 31123 -> 31123
#                  '使': 54783 -> 54783
#                 '您的': 33379 -> 33379
#                 '风格': 32799 -> 32799
#                 '更加': 31923 -> 31923
#                 '出众': 44425 -> 44425
#                  '。': 31155 -> 31155
#                 '就算': 33838 -> 33838
#                  '单': 54838 -> 54838
#                  '从': 54708 -> 54708
#                  '选': 54878 -> 54878
#                  '料': 54980 -> 54980
#                  '上': 54547 -> 54547
#                 '来说': 31870 -> 31870
#                  '，': 31123 -> 31123
#                 '这款': 33730 -> 33730
#                  'p': 30925 -> 30925
#                'olo': 9795 -> 9795
#                  '衫': 57439 -> 57439
#                '的颜色': 44476 -> 44476
#                 '沉稳': 48765 -> 48765
#                 '经典': 32698 -> 32698
#                  '，': 31123 -> 31123
#                  '是': 54532 -> 54532
#                 '这个': 31646 -> 31646
#                 '季度': 33557 -> 33557
#                 '十分': 32177 -> 32177
#                  '受': 54777 -> 54777
#                 '大众': 33554 -> 33554
#                '喜爱的': 44064 -> 44064
#                 '风格': 32799 -> 32799
#                  '了': 54537 -> 54537
#                  '，': 31123 -> 31123
#                 '而且': 31828 -> 31828
#                 '兼具': 44519 -> 44519
#                 '舒适': 33894 -> 33894
#                 '感和': 36151 -> 36151
#                 '时尚': 33481 -> 33481
#                  '感': 54706 -> 54706
#                  '。': 31155 -> 31155
#           '<|user|>': 64795 -> 64795
#                   '': 30910 -> -100
#                 '\n': 13 -> -100
#                   '': 30910 -> -100
#                 '类型': 33467 -> -100
#                  '#': 31010 -> -100
#                 '上衣': 49534 -> -100
#                  '*': 30998 -> -100
#                  '版': 55090 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                  'h': 30919 -> -100
#                  '*': 30998 -> -100
#                 '材质': 38317 -> -100
#                  '#': 31010 -> -100
#                  '蚕': 58186 -> -100
#                  '丝': 55599 -> -100
#                  '*': 30998 -> -100
#                 '风格': 32799 -> -100
#                  '#': 31010 -> -100
#                 '复古': 44785 -> -100
#                  '*': 30998 -> -100
#                 '图案': 37505 -> -100
#                  '#': 31010 -> -100
#                  '条': 54907 -> -100
#                  '纹': 56487 -> -100
#                  '*': 30998 -> -100
#                 '图案': 37505 -> -100
#                  '#': 31010 -> -100
#                 '复古': 44785 -> -100
#                  '*': 30998 -> -100
#                 '图案': 37505 -> -100
#                  '#': 31010 -> -100
#                  '撞': 56483 -> -100
#                  '色': 54785 -> -100
#                  '*': 30998 -> -100
#                  '衣': 55500 -> -100
#                 '样式': 46025 -> -100
#                  '#': 31010 -> -100
#                 '衬衫': 44109 -> -100
#                  '*': 30998 -> -100
#                  '衣': 55500 -> -100
#                  '领': 54847 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                  '小': 54603 -> -100
#                  '立': 54748 -> -100
#                  '领': 54847 -> -100
#      '<|assistant|>': 64796 -> -100
#                   '': 30910 -> 30910
#                 '\n': 13 -> 13
#                  '小': 35182 -> 35182
#                 '女人': 31997 -> 31997
#                '十足的': 48416 -> 48416
#                  '条': 54907 -> 54907
#                  '纹': 56487 -> 56487
#                  '衬': 57342 -> 57342
#                  '衣': 55500 -> 55500
#                  '，': 31123 -> 31123
#                  '缎': 59669 -> 59669
#                  '面': 54610 -> 54610
#                 '一点': 32264 -> 32264
#                 '点的': 35490 -> 35490
#                 '复古': 44785 -> 44785
#                  '，': 31123 -> 31123
#                 '还有': 31843 -> 31843
#                  '蓝': 55791 -> 55791
#                 '绿色': 32658 -> 32658
#                 '这种': 31758 -> 31758
#                 '高级': 32970 -> 32970
#                 '气质': 34219 -> 34219
#                 '复古': 44785 -> 44785
#                  '色': 54785 -> 54785
#                  '，': 31123 -> 31123
#                  '真': 54792 -> 54792
#                  '丝': 55599 -> 55599
#                 '材质': 38317 -> 38317
#                  '，': 31123 -> 31123
#                  '撞': 56483 -> 56483
#                  '色': 54785 -> 54785
#                  '竖': 57771 -> 57771
#                  '条': 54907 -> 54907
#                  '纹': 56487 -> 56487
#                '特别的': 38084 -> 38084
#                 '现代': 31999 -> 31999
#                  '感': 54706 -> 54706
#                 '味道': 33548 -> 33548
#                  '，': 31123 -> 31123
#                  '直': 54839 -> 54839
# max_steps is given, it will override any value given in num_train_epochs
# ***** Running training *****
#   Num examples = 1
#   Num Epochs = 3,000
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 3,000
#   Number of trainable parameters = 1,949,696
# {'loss': 4.7945, 'grad_norm': 2.028484344482422, 'learning_rate': 4.9833333333333336e-05, 'epoch': 10.0}
# {'loss': 4.3297, 'grad_norm': 2.220525026321411, 'learning_rate': 4.966666666666667e-05, 'epoch': 20.0}
# {'loss': 3.7559, 'grad_norm': 2.3366270065307617, 'learning_rate': 4.9500000000000004e-05, 'epoch': 30.0}
# {'loss': 3.1477, 'grad_norm': 2.8433964252471924, 'learning_rate': 4.933333333333334e-05, 'epoch': 40.0}
# {'loss': 2.4416, 'grad_norm': 2.9666924476623535, 'learning_rate': 4.9166666666666665e-05, 'epoch': 50.0}
# {'loss': 1.6596, 'grad_norm': 2.867058515548706, 'learning_rate': 4.9e-05, 'epoch': 60.0}
# {'loss': 0.8919, 'grad_norm': 2.2925379276275635, 'learning_rate': 4.883333333333334e-05, 'epoch': 70.0}
# {'loss': 0.3195, 'grad_norm': 1.1362355947494507, 'learning_rate': 4.866666666666667e-05, 'epoch': 80.0}
# {'loss': 0.0749, 'grad_norm': 0.5127453207969666, 'learning_rate': 4.85e-05, 'epoch': 90.0}
# {'loss': 0.0299, 'grad_norm': 0.3914127051830292, 'learning_rate': 4.8333333333333334e-05, 'epoch': 100.0}
# {'loss': 0.0244, 'grad_norm': 0.3575468063354492, 'learning_rate': 4.8166666666666674e-05, 'epoch': 110.0}
# {'loss': 0.0268, 'grad_norm': 0.3359096348285675, 'learning_rate': 4.8e-05, 'epoch': 120.0}
# {'loss': 0.0281, 'grad_norm': 0.3355039060115814, 'learning_rate': 4.7833333333333335e-05, 'epoch': 130.0}
# {'loss': 0.0302, 'grad_norm': 0.34532517194747925, 'learning_rate': 4.766666666666667e-05, 'epoch': 140.0}
# {'loss': 0.0322, 'grad_norm': 0.3581864833831787, 'learning_rate': 4.75e-05, 'epoch': 150.0}
# {'loss': 0.0346, 'grad_norm': 0.3787911534309387, 'learning_rate': 4.7333333333333336e-05, 'epoch': 160.0}
# {'loss': 0.0371, 'grad_norm': 0.3976178765296936, 'learning_rate': 4.716666666666667e-05, 'epoch': 170.0}
# {'loss': 0.0399, 'grad_norm': 0.42643147706985474, 'learning_rate': 4.7e-05, 'epoch': 180.0}
# {'loss': 0.0432, 'grad_norm': 0.44638121128082275, 'learning_rate': 4.683333333333334e-05, 'epoch': 190.0}
# {'loss': 0.0461, 'grad_norm': 0.4643804728984833, 'learning_rate': 4.666666666666667e-05, 'epoch': 200.0}
# {'loss': 0.0492, 'grad_norm': 0.5535054206848145, 'learning_rate': 4.6500000000000005e-05, 'epoch': 210.0}
# {'loss': 0.0523, 'grad_norm': 0.7737544178962708, 'learning_rate': 4.633333333333333e-05, 'epoch': 220.0}
# {'loss': 0.0562, 'grad_norm': 0.5615922808647156, 'learning_rate': 4.6166666666666666e-05, 'epoch': 230.0}
# {'loss': 0.0593, 'grad_norm': 0.7343789339065552, 'learning_rate': 4.600000000000001e-05, 'epoch': 240.0}
# {'loss': 0.0639, 'grad_norm': 0.9312736988067627, 'learning_rate': 4.5833333333333334e-05, 'epoch': 250.0}
# {'loss': 0.068, 'grad_norm': 1.3138389587402344, 'learning_rate': 4.566666666666667e-05, 'epoch': 260.0}
# {'loss': 0.0708, 'grad_norm': 1.0968296527862549, 'learning_rate': 4.55e-05, 'epoch': 270.0}
# {'loss': 0.0741, 'grad_norm': 1.5897458791732788, 'learning_rate': 4.5333333333333335e-05, 'epoch': 280.0}
# {'loss': 0.0835, 'grad_norm': 7.157574653625488, 'learning_rate': 4.516666666666667e-05, 'epoch': 290.0}
# {'loss': 0.0771, 'grad_norm': 2.1373753547668457, 'learning_rate': 4.5e-05, 'epoch': 300.0}
# {'loss': 0.0856, 'grad_norm': 2.699070453643799, 'learning_rate': 4.483333333333333e-05, 'epoch': 310.0}
# {'loss': 0.085, 'grad_norm': 2.8163719177246094, 'learning_rate': 4.466666666666667e-05, 'epoch': 320.0}
# {'loss': 0.0891, 'grad_norm': 4.641617774963379, 'learning_rate': 4.4500000000000004e-05, 'epoch': 330.0}
# {'loss': 0.0869, 'grad_norm': 3.2052669525146484, 'learning_rate': 4.433333333333334e-05, 'epoch': 340.0}
# {'loss': 0.0941, 'grad_norm': 2.7480268478393555, 'learning_rate': 4.4166666666666665e-05, 'epoch': 350.0}
# {'loss': 0.0926, 'grad_norm': 3.3653435707092285, 'learning_rate': 4.4000000000000006e-05, 'epoch': 360.0}
# {'loss': 0.1008, 'grad_norm': 5.718459606170654, 'learning_rate': 4.383333333333334e-05, 'epoch': 370.0}
# {'loss': 0.0956, 'grad_norm': 4.161947727203369, 'learning_rate': 4.3666666666666666e-05, 'epoch': 380.0}
# {'loss': 0.105, 'grad_norm': 5.7758378982543945, 'learning_rate': 4.35e-05, 'epoch': 390.0}
# {'loss': 0.1006, 'grad_norm': 4.075742721557617, 'learning_rate': 4.3333333333333334e-05, 'epoch': 400.0}
# {'loss': 0.1068, 'grad_norm': 4.448358535766602, 'learning_rate': 4.316666666666667e-05, 'epoch': 410.0}
# {'loss': 0.1072, 'grad_norm': 7.128978252410889, 'learning_rate': 4.3e-05, 'epoch': 420.0}
# {'loss': 0.1072, 'grad_norm': 7.414681434631348, 'learning_rate': 4.2833333333333335e-05, 'epoch': 430.0}
# {'loss': 0.1113, 'grad_norm': 6.023709774017334, 'learning_rate': 4.266666666666667e-05, 'epoch': 440.0}
# {'loss': 0.1139, 'grad_norm': 5.804068565368652, 'learning_rate': 4.25e-05, 'epoch': 450.0}
# {'loss': 0.116, 'grad_norm': 6.811020374298096, 'learning_rate': 4.233333333333334e-05, 'epoch': 460.0}
# {'loss': 0.117, 'grad_norm': 5.980651378631592, 'learning_rate': 4.216666666666667e-05, 'epoch': 470.0}
# {'loss': 0.1183, 'grad_norm': 7.836266040802002, 'learning_rate': 4.2e-05, 'epoch': 480.0}
# {'loss': 0.1204, 'grad_norm': 7.210332870483398, 'learning_rate': 4.183333333333334e-05, 'epoch': 490.0}
# {'loss': 0.1221, 'grad_norm': 9.027328491210938, 'learning_rate': 4.166666666666667e-05, 'epoch': 500.0}
#  17%|██████▋                                 | 500/3000 [08:10<40:56,  1.02it/s]***** Running Evaluation *****
#   Num examples = 3
#   Batch size = 16
#
#   0%|                                                     | 0/1 [00:00<?, ?it/s]Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.734 seconds.
# Prefix dict has been built successfully.
#
# {'eval_rouge-1': 11.270966666666666, 'eval_rouge-2': 0.34723333333333334, 'eval_rouge-l': 10.540500000000002, 'eval_bleu-4': 0.007453963069131997, 'eval_runtime': 7.995, 'eval_samples_per_second': 0.375, 'eval_steps_per_second': 0.125, 'epoch': 500.0}
#  17%|██████▋                                 | 500/3000 [08:18<40:56,  1.02it/s]
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  1.31it/s]
#                                                                                 Saving model checkpoint to ./output/checkpoint-500
# /root/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /root/onethingai-fs/models/hub/models--THUDM--chatglm3-6b/snapshots/91a0561caa089280e94bf26a9fc3530482f0fe60/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 0.1271, 'grad_norm': 13.062721252441406, 'learning_rate': 4.15e-05, 'epoch': 510.0}
# {'loss': 0.126, 'grad_norm': 7.766993045806885, 'learning_rate': 4.133333333333333e-05, 'epoch': 520.0}
# {'loss': 0.1278, 'grad_norm': 13.832517623901367, 'learning_rate': 4.116666666666667e-05, 'epoch': 530.0}
# {'loss': 0.1286, 'grad_norm': 8.149085998535156, 'learning_rate': 4.1e-05, 'epoch': 540.0}
# {'loss': 0.1303, 'grad_norm': 7.8765387535095215, 'learning_rate': 4.0833333333333334e-05, 'epoch': 550.0}
# {'loss': 0.1328, 'grad_norm': 8.715567588806152, 'learning_rate': 4.066666666666667e-05, 'epoch': 560.0}
# {'loss': 0.1324, 'grad_norm': 13.63605785369873, 'learning_rate': 4.05e-05, 'epoch': 570.0}
# {'loss': 0.1328, 'grad_norm': 14.457502365112305, 'learning_rate': 4.0333333333333336e-05, 'epoch': 580.0}
# {'loss': 0.1359, 'grad_norm': 8.58793830871582, 'learning_rate': 4.016666666666667e-05, 'epoch': 590.0}
# {'loss': 0.1356, 'grad_norm': 8.531230926513672, 'learning_rate': 4e-05, 'epoch': 600.0}
# {'loss': 0.1416, 'grad_norm': 18.441558837890625, 'learning_rate': 3.983333333333333e-05, 'epoch': 610.0}
# {'loss': 0.1411, 'grad_norm': 11.626513481140137, 'learning_rate': 3.966666666666667e-05, 'epoch': 620.0}
# {'loss': 0.1406, 'grad_norm': 11.596136093139648, 'learning_rate': 3.9500000000000005e-05, 'epoch': 630.0}
# {'loss': 0.1424, 'grad_norm': 14.525834083557129, 'learning_rate': 3.933333333333333e-05, 'epoch': 640.0}
# {'loss': 0.1462, 'grad_norm': 15.440744400024414, 'learning_rate': 3.9166666666666665e-05, 'epoch': 650.0}
# {'loss': 0.149, 'grad_norm': 14.363625526428223, 'learning_rate': 3.9000000000000006e-05, 'epoch': 660.0}
# {'loss': 0.1439, 'grad_norm': 14.579361915588379, 'learning_rate': 3.883333333333333e-05, 'epoch': 670.0}
# {'loss': 0.1481, 'grad_norm': 11.883875846862793, 'learning_rate': 3.866666666666667e-05, 'epoch': 680.0}
# {'loss': 0.1503, 'grad_norm': 13.576114654541016, 'learning_rate': 3.85e-05, 'epoch': 690.0}
# {'loss': 0.1516, 'grad_norm': 15.310234069824219, 'learning_rate': 3.8333333333333334e-05, 'epoch': 700.0}
# {'loss': 0.1538, 'grad_norm': 18.155719757080078, 'learning_rate': 3.816666666666667e-05, 'epoch': 710.0}
# {'loss': 0.1521, 'grad_norm': 15.362018585205078, 'learning_rate': 3.8e-05, 'epoch': 720.0}
# {'loss': 0.1532, 'grad_norm': 20.655418395996094, 'learning_rate': 3.7833333333333336e-05, 'epoch': 730.0}
# {'loss': 0.153, 'grad_norm': 18.40489387512207, 'learning_rate': 3.766666666666667e-05, 'epoch': 740.0}
# {'loss': 0.1561, 'grad_norm': 19.233291625976562, 'learning_rate': 3.7500000000000003e-05, 'epoch': 750.0}
# {'loss': 0.1583, 'grad_norm': 21.933103561401367, 'learning_rate': 3.733333333333334e-05, 'epoch': 760.0}
# {'loss': 0.1546, 'grad_norm': 20.78990364074707, 'learning_rate': 3.7166666666666664e-05, 'epoch': 770.0}
# {'loss': 0.1575, 'grad_norm': 18.091381072998047, 'learning_rate': 3.7e-05, 'epoch': 780.0}
# {'loss': 0.1558, 'grad_norm': 19.188440322875977, 'learning_rate': 3.683333333333334e-05, 'epoch': 790.0}
# {'loss': 0.1621, 'grad_norm': 18.7522029876709, 'learning_rate': 3.6666666666666666e-05, 'epoch': 800.0}
# {'loss': 0.1581, 'grad_norm': 23.06739044189453, 'learning_rate': 3.65e-05, 'epoch': 810.0}
# {'loss': 0.1622, 'grad_norm': 20.043865203857422, 'learning_rate': 3.633333333333333e-05, 'epoch': 820.0}
# {'loss': 0.1611, 'grad_norm': 32.32014846801758, 'learning_rate': 3.6166666666666674e-05, 'epoch': 830.0}
# {'loss': 0.1643, 'grad_norm': 26.287153244018555, 'learning_rate': 3.6e-05, 'epoch': 840.0}
# {'loss': 0.1634, 'grad_norm': 18.85346221923828, 'learning_rate': 3.5833333333333335e-05, 'epoch': 850.0}
# {'loss': 0.166, 'grad_norm': 20.141122817993164, 'learning_rate': 3.566666666666667e-05, 'epoch': 860.0}
# {'loss': 0.1666, 'grad_norm': 27.369199752807617, 'learning_rate': 3.55e-05, 'epoch': 870.0}
# {'loss': 0.166, 'grad_norm': 25.525545120239258, 'learning_rate': 3.5333333333333336e-05, 'epoch': 880.0}
# {'loss': 0.1655, 'grad_norm': 19.44550895690918, 'learning_rate': 3.516666666666667e-05, 'epoch': 890.0}
# {'loss': 0.1705, 'grad_norm': 21.17098617553711, 'learning_rate': 3.5e-05, 'epoch': 900.0}
# {'loss': 0.1689, 'grad_norm': 29.96238899230957, 'learning_rate': 3.483333333333334e-05, 'epoch': 910.0}
# {'loss': 0.1697, 'grad_norm': 29.798816680908203, 'learning_rate': 3.466666666666667e-05, 'epoch': 920.0}
# {'loss': 0.1732, 'grad_norm': 33.472652435302734, 'learning_rate': 3.45e-05, 'epoch': 930.0}
# {'loss': 0.1697, 'grad_norm': 25.91464614868164, 'learning_rate': 3.433333333333333e-05, 'epoch': 940.0}
# {'loss': 0.1782, 'grad_norm': 27.419593811035156, 'learning_rate': 3.4166666666666666e-05, 'epoch': 950.0}
# {'loss': 0.1682, 'grad_norm': 24.839885711669922, 'learning_rate': 3.4000000000000007e-05, 'epoch': 960.0}
# {'loss': 0.1722, 'grad_norm': 25.209718704223633, 'learning_rate': 3.3833333333333334e-05, 'epoch': 970.0}
# {'loss': 0.1765, 'grad_norm': 26.04128646850586, 'learning_rate': 3.366666666666667e-05, 'epoch': 980.0}
# {'loss': 0.1745, 'grad_norm': 44.08474349975586, 'learning_rate': 3.35e-05, 'epoch': 990.0}
# {'loss': 0.1773, 'grad_norm': 22.746950149536133, 'learning_rate': 3.3333333333333335e-05, 'epoch': 1000.0}
#  33%|█████████████                          | 1000/3000 [17:14<35:32,  1.07s/it]***** Running Evaluation *****
#   Num examples = 3
#   Batch size = 16
#
#
# {'eval_rouge-1': 8.424466666666666, 'eval_rouge-2': 0.6968666666666666, 'eval_rouge-l': 6.075233333333333, 'eval_bleu-4': 0.003972989580967421, 'eval_runtime': 13.6254, 'eval_samples_per_second': 0.22, 'eval_steps_per_second': 0.073, 'epoch': 1000.0}
#  33%|█████████████                          | 1000/3000 [17:28<35:32,  1.07s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 24.22it/s]
#                                                                                 Saving model checkpoint to ./output/checkpoint-1000
# /root/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /root/onethingai-fs/models/hub/models--THUDM--chatglm3-6b/snapshots/91a0561caa089280e94bf26a9fc3530482f0fe60/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 0.1745, 'grad_norm': 29.231273651123047, 'learning_rate': 3.316666666666667e-05, 'epoch': 1010.0}
# {'loss': 0.1768, 'grad_norm': 25.812747955322266, 'learning_rate': 3.3e-05, 'epoch': 1020.0}
# {'loss': 0.1778, 'grad_norm': 29.785900115966797, 'learning_rate': 3.283333333333333e-05, 'epoch': 1030.0}
# {'loss': 0.1815, 'grad_norm': 48.080997467041016, 'learning_rate': 3.266666666666667e-05, 'epoch': 1040.0}
# {'loss': 0.1895, 'grad_norm': 35.88494873046875, 'learning_rate': 3.2500000000000004e-05, 'epoch': 1050.0}
# {'loss': 0.1784, 'grad_norm': 33.28261184692383, 'learning_rate': 3.233333333333333e-05, 'epoch': 1060.0}
# {'loss': 0.1848, 'grad_norm': 31.952098846435547, 'learning_rate': 3.2166666666666665e-05, 'epoch': 1070.0}
# {'loss': 0.1837, 'grad_norm': 33.27830505371094, 'learning_rate': 3.2000000000000005e-05, 'epoch': 1080.0}
# {'loss': 0.1857, 'grad_norm': 41.17156219482422, 'learning_rate': 3.183333333333334e-05, 'epoch': 1090.0}
# {'loss': 0.1829, 'grad_norm': 37.04552459716797, 'learning_rate': 3.1666666666666666e-05, 'epoch': 1100.0}
# {'loss': 0.1827, 'grad_norm': 31.07703971862793, 'learning_rate': 3.15e-05, 'epoch': 1110.0}
# {'loss': 0.1857, 'grad_norm': 49.57438659667969, 'learning_rate': 3.1333333333333334e-05, 'epoch': 1120.0}
# {'loss': 0.1876, 'grad_norm': 47.40774917602539, 'learning_rate': 3.116666666666667e-05, 'epoch': 1130.0}
# {'loss': 0.1883, 'grad_norm': 44.05558776855469, 'learning_rate': 3.1e-05, 'epoch': 1140.0}
# {'loss': 0.1903, 'grad_norm': 60.21760559082031, 'learning_rate': 3.0833333333333335e-05, 'epoch': 1150.0}
# {'loss': 0.1911, 'grad_norm': 48.162109375, 'learning_rate': 3.066666666666667e-05, 'epoch': 1160.0}
# {'loss': 0.1833, 'grad_norm': 25.249765396118164, 'learning_rate': 3.05e-05, 'epoch': 1170.0}
# {'loss': 0.1931, 'grad_norm': 36.4158935546875, 'learning_rate': 3.0333333333333337e-05, 'epoch': 1180.0}
# ...
# {'loss': 0.2218, 'grad_norm': 83.76020050048828, 'learning_rate': 1.5666666666666667e-05, 'epoch': 2060.0}
# {'loss': 0.2216, 'grad_norm': 111.49747467041016, 'learning_rate': 1.55e-05, 'epoch': 2070.0}
# {'loss': 0.2251, 'grad_norm': 104.10102844238281, 'learning_rate': 1.5333333333333334e-05, 'epoch': 2080.0}
# {'loss': 0.2218, 'grad_norm': 72.727783203125, 'learning_rate': 1.5166666666666668e-05, 'epoch': 2090.0}
# {'loss': 0.2209, 'grad_norm': 64.1226806640625, 'learning_rate': 1.5e-05, 'epoch': 2100.0}
# {'loss': 0.2206, 'grad_norm': 78.01239013671875, 'learning_rate': 1.4833333333333336e-05, 'epoch': 2110.0}
# {'loss': 0.2201, 'grad_norm': 44.09861373901367, 'learning_rate': 1.4666666666666668e-05, 'epoch': 2120.0}
# {'loss': 0.2201, 'grad_norm': 92.39473724365234, 'learning_rate': 1.45e-05, 'epoch': 2130.0}
# {'loss': 0.2232, 'grad_norm': 68.21626281738281, 'learning_rate': 1.4333333333333334e-05, 'epoch': 2140.0}
# {'loss': 0.2309, 'grad_norm': 90.58747863769531, 'learning_rate': 1.4166666666666668e-05, 'epoch': 2150.0}
# {'loss': 0.2161, 'grad_norm': 64.56990814208984, 'learning_rate': 1.4000000000000001e-05, 'epoch': 2160.0}
# {'loss': 0.2204, 'grad_norm': 80.22166442871094, 'learning_rate': 1.3833333333333334e-05, 'epoch': 2170.0}
# {'loss': 0.2234, 'grad_norm': 60.10667419433594, 'learning_rate': 1.3666666666666666e-05, 'epoch': 2180.0}
# {'loss': 0.2133, 'grad_norm': 79.06864166259766, 'learning_rate': 1.3500000000000001e-05, 'epoch': 2190.0}
# {'loss': 0.2201, 'grad_norm': 70.53633117675781, 'learning_rate': 1.3333333333333333e-05, 'epoch': 2200.0}
# {'loss': 0.2223, 'grad_norm': 103.79463195800781, 'learning_rate': 1.3166666666666665e-05, 'epoch': 2210.0}
# {'loss': 0.2229, 'grad_norm': 100.46571350097656, 'learning_rate': 1.3000000000000001e-05, 'epoch': 2220.0}
# {'loss': 0.2174, 'grad_norm': 66.5364990234375, 'learning_rate': 1.2833333333333333e-05, 'epoch': 2230.0}
# {'loss': 0.2205, 'grad_norm': 77.61109161376953, 'learning_rate': 1.2666666666666668e-05, 'epoch': 2240.0}
# {'loss': 0.2239, 'grad_norm': 99.8065185546875, 'learning_rate': 1.25e-05, 'epoch': 2250.0}
# {'loss': 0.2259, 'grad_norm': 92.73318481445312, 'learning_rate': 1.2333333333333334e-05, 'epoch': 2260.0}
# {'loss': 0.2183, 'grad_norm': 63.275630950927734, 'learning_rate': 1.2166666666666668e-05, 'epoch': 2270.0}
# {'loss': 0.2201, 'grad_norm': 89.22998046875, 'learning_rate': 1.2e-05, 'epoch': 2280.0}
# {'loss': 0.2274, 'grad_norm': 82.8819351196289, 'learning_rate': 1.1833333333333334e-05, 'epoch': 2290.0}
# {'loss': 0.2254, 'grad_norm': 85.79212188720703, 'learning_rate': 1.1666666666666668e-05, 'epoch': 2300.0}
# {'loss': 0.2282, 'grad_norm': 123.57350158691406, 'learning_rate': 1.1500000000000002e-05, 'epoch': 2310.0}
# {'loss': 0.2209, 'grad_norm': 98.25617980957031, 'learning_rate': 1.1333333333333334e-05, 'epoch': 2320.0}
# {'loss': 0.219, 'grad_norm': 90.43968963623047, 'learning_rate': 1.1166666666666668e-05, 'epoch': 2330.0}
# {'loss': 0.2179, 'grad_norm': 88.55291748046875, 'learning_rate': 1.1000000000000001e-05, 'epoch': 2340.0}
# {'loss': 0.2179, 'grad_norm': 63.412559509277344, 'learning_rate': 1.0833333333333334e-05, 'epoch': 2350.0}
# {'loss': 0.2245, 'grad_norm': 66.91474914550781, 'learning_rate': 1.0666666666666667e-05, 'epoch': 2360.0}
# {'loss': 0.2161, 'grad_norm': 58.19095230102539, 'learning_rate': 1.05e-05, 'epoch': 2370.0}
# {'loss': 0.2227, 'grad_norm': 77.03477478027344, 'learning_rate': 1.0333333333333333e-05, 'epoch': 2380.0}
# {'loss': 0.2196, 'grad_norm': 60.17494201660156, 'learning_rate': 1.0166666666666667e-05, 'epoch': 2390.0}
# {'loss': 0.2216, 'grad_norm': 41.08332824707031, 'learning_rate': 1e-05, 'epoch': 2400.0}
# {'loss': 0.2219, 'grad_norm': 65.34111022949219, 'learning_rate': 9.833333333333333e-06, 'epoch': 2410.0}
# {'loss': 0.2212, 'grad_norm': 68.04833984375, 'learning_rate': 9.666666666666667e-06, 'epoch': 2420.0}
# {'loss': 0.2298, 'grad_norm': 106.04212951660156, 'learning_rate': 9.5e-06, 'epoch': 2430.0}
# {'loss': 0.2266, 'grad_norm': 85.96221923828125, 'learning_rate': 9.333333333333334e-06, 'epoch': 2440.0}
# {'loss': 0.222, 'grad_norm': 50.515220642089844, 'learning_rate': 9.166666666666666e-06, 'epoch': 2450.0}
# {'loss': 0.225, 'grad_norm': 59.12119674682617, 'learning_rate': 9e-06, 'epoch': 2460.0}
# {'loss': 0.2195, 'grad_norm': 69.01286315917969, 'learning_rate': 8.833333333333334e-06, 'epoch': 2470.0}
# {'loss': 0.223, 'grad_norm': 83.05947875976562, 'learning_rate': 8.666666666666668e-06, 'epoch': 2480.0}
# {'loss': 0.2207, 'grad_norm': 63.919044494628906, 'learning_rate': 8.500000000000002e-06, 'epoch': 2490.0}
# {'loss': 0.228, 'grad_norm': 123.4032974243164, 'learning_rate': 8.333333333333334e-06, 'epoch': 2500.0}
#  83%|████████████████████████████████▌      | 2500/3000 [38:44<06:47,  1.23it/s]***** Running Evaluation *****
#   Num examples = 3
#   Batch size = 16
#
#
# {'eval_rouge-1': 6.9926666666666675, 'eval_rouge-2': 0.3788, 'eval_rouge-l': 4.8567, 'eval_bleu-4': 0.0018897920066298021, 'eval_runtime': 11.8884, 'eval_samples_per_second': 0.252, 'eval_steps_per_second': 0.084, 'epoch': 2500.0}
#  83%|████████████████████████████████▌      | 2500/3000 [38:56<06:47,  1.23it/s]
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 16.45it/s]
#                                                                                 Saving model checkpoint to ./output/checkpoint-2500
# /root/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /root/onethingai-fs/models/hub/models--THUDM--chatglm3-6b/snapshots/91a0561caa089280e94bf26a9fc3530482f0fe60/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 0.2236, 'grad_norm': 94.99830627441406, 'learning_rate': 8.166666666666668e-06, 'epoch': 2510.0}
# {'loss': 0.2232, 'grad_norm': 93.23636627197266, 'learning_rate': 8.000000000000001e-06, 'epoch': 2520.0}
# {'loss': 0.2262, 'grad_norm': 76.89525604248047, 'learning_rate': 7.833333333333333e-06, 'epoch': 2530.0}
# {'loss': 0.2234, 'grad_norm': 89.30651092529297, 'learning_rate': 7.666666666666667e-06, 'epoch': 2540.0}
# {'loss': 0.2327, 'grad_norm': 68.57455444335938, 'learning_rate': 7.5e-06, 'epoch': 2550.0}
# {'loss': 0.2193, 'grad_norm': 68.03072357177734, 'learning_rate': 7.333333333333334e-06, 'epoch': 2560.0}
# {'loss': 0.2225, 'grad_norm': 77.4955062866211, 'learning_rate': 7.166666666666667e-06, 'epoch': 2570.0}
# {'loss': 0.218, 'grad_norm': 56.184879302978516, 'learning_rate': 7.000000000000001e-06, 'epoch': 2580.0}
# {'loss': 0.2281, 'grad_norm': 85.90138244628906, 'learning_rate': 6.833333333333333e-06, 'epoch': 2590.0}
# {'loss': 0.2316, 'grad_norm': 123.85768127441406, 'learning_rate': 6.666666666666667e-06, 'epoch': 2600.0}
# {'loss': 0.2217, 'grad_norm': 56.09712600708008, 'learning_rate': 6.5000000000000004e-06, 'epoch': 2610.0}
# {'loss': 0.2241, 'grad_norm': 60.39081573486328, 'learning_rate': 6.333333333333334e-06, 'epoch': 2620.0}
# {'loss': 0.2279, 'grad_norm': 45.85734558105469, 'learning_rate': 6.166666666666667e-06, 'epoch': 2630.0}
# {'loss': 0.2292, 'grad_norm': 71.50588989257812, 'learning_rate': 6e-06, 'epoch': 2640.0}
# {'loss': 0.2206, 'grad_norm': 46.794952392578125, 'learning_rate': 5.833333333333334e-06, 'epoch': 2650.0}
# {'loss': 0.2256, 'grad_norm': 55.16497039794922, 'learning_rate': 5.666666666666667e-06, 'epoch': 2660.0}
# {'loss': 0.2251, 'grad_norm': 67.21837615966797, 'learning_rate': 5.500000000000001e-06, 'epoch': 2670.0}
# {'loss': 0.2275, 'grad_norm': 77.20565795898438, 'learning_rate': 5.333333333333334e-06, 'epoch': 2680.0}
# {'loss': 0.225, 'grad_norm': 64.57868957519531, 'learning_rate': 5.166666666666667e-06, 'epoch': 2690.0}
# {'loss': 0.2265, 'grad_norm': 83.44708251953125, 'learning_rate': 5e-06, 'epoch': 2700.0}
# {'loss': 0.2248, 'grad_norm': 65.1061782836914, 'learning_rate': 4.833333333333333e-06, 'epoch': 2710.0}
# {'loss': 0.2253, 'grad_norm': 98.24759674072266, 'learning_rate': 4.666666666666667e-06, 'epoch': 2720.0}
# {'loss': 0.224, 'grad_norm': 57.18075942993164, 'learning_rate': 4.5e-06, 'epoch': 2730.0}
# {'loss': 0.2245, 'grad_norm': 59.71771240234375, 'learning_rate': 4.333333333333334e-06, 'epoch': 2740.0}
# {'loss': 0.2234, 'grad_norm': 61.442501068115234, 'learning_rate': 4.166666666666667e-06, 'epoch': 2750.0}
# {'loss': 0.2202, 'grad_norm': 66.4646987915039, 'learning_rate': 4.000000000000001e-06, 'epoch': 2760.0}
# {'loss': 0.2241, 'grad_norm': 81.45802307128906, 'learning_rate': 3.833333333333334e-06, 'epoch': 2770.0}
# {'loss': 0.2233, 'grad_norm': 66.38644409179688, 'learning_rate': 3.666666666666667e-06, 'epoch': 2780.0}
# {'loss': 0.2238, 'grad_norm': 75.30754089355469, 'learning_rate': 3.5000000000000004e-06, 'epoch': 2790.0}
# {'loss': 0.2227, 'grad_norm': 61.08626174926758, 'learning_rate': 3.3333333333333333e-06, 'epoch': 2800.0}
# {'loss': 0.2237, 'grad_norm': 77.20498657226562, 'learning_rate': 3.166666666666667e-06, 'epoch': 2810.0}
# {'loss': 0.2253, 'grad_norm': 73.71534729003906, 'learning_rate': 3e-06, 'epoch': 2820.0}
# {'loss': 0.2261, 'grad_norm': 79.19720458984375, 'learning_rate': 2.8333333333333335e-06, 'epoch': 2830.0}
# {'loss': 0.22, 'grad_norm': 59.324710845947266, 'learning_rate': 2.666666666666667e-06, 'epoch': 2840.0}
# {'loss': 0.2225, 'grad_norm': 66.179443359375, 'learning_rate': 2.5e-06, 'epoch': 2850.0}
# {'loss': 0.2242, 'grad_norm': 50.839210510253906, 'learning_rate': 2.3333333333333336e-06, 'epoch': 2860.0}
# {'loss': 0.2246, 'grad_norm': 47.84612274169922, 'learning_rate': 2.166666666666667e-06, 'epoch': 2870.0}
# {'loss': 0.2239, 'grad_norm': 91.73995971679688, 'learning_rate': 2.0000000000000003e-06, 'epoch': 2880.0}
# {'loss': 0.2182, 'grad_norm': 62.31117248535156, 'learning_rate': 1.8333333333333335e-06, 'epoch': 2890.0}
# {'loss': 0.2231, 'grad_norm': 39.68555450439453, 'learning_rate': 1.6666666666666667e-06, 'epoch': 2900.0}
# {'loss': 0.221, 'grad_norm': 57.614830017089844, 'learning_rate': 1.5e-06, 'epoch': 2910.0}
# {'loss': 0.2218, 'grad_norm': 47.82111358642578, 'learning_rate': 1.3333333333333334e-06, 'epoch': 2920.0}
# {'loss': 0.2252, 'grad_norm': 56.10527038574219, 'learning_rate': 1.1666666666666668e-06, 'epoch': 2930.0}
# {'loss': 0.2211, 'grad_norm': 33.92952346801758, 'learning_rate': 1.0000000000000002e-06, 'epoch': 2940.0}
# {'loss': 0.2249, 'grad_norm': 44.00542068481445, 'learning_rate': 8.333333333333333e-07, 'epoch': 2950.0}
# {'loss': 0.224, 'grad_norm': 59.24022674560547, 'learning_rate': 6.666666666666667e-07, 'epoch': 2960.0}
# {'loss': 0.2201, 'grad_norm': 32.61418151855469, 'learning_rate': 5.000000000000001e-07, 'epoch': 2970.0}
# {'loss': 0.2245, 'grad_norm': 41.21982955932617, 'learning_rate': 3.3333333333333335e-07, 'epoch': 2980.0}
# {'loss': 0.227, 'grad_norm': 39.67049026489258, 'learning_rate': 1.6666666666666668e-07, 'epoch': 2990.0}
# {'loss': 0.2175, 'grad_norm': 35.805564880371094, 'learning_rate': 0.0, 'epoch': 3000.0}
# 100%|███████████████████████████████████████| 3000/3000 [44:36<00:00,  1.47it/s]***** Running Evaluation *****
#   Num examples = 3
#   Batch size = 16
#
#
# {'eval_rouge-1': 7.4026, 'eval_rouge-2': 0.36710000000000004, 'eval_rouge-l': 5.182833333333334, 'eval_bleu-4': 0.0021228428467801315, 'eval_runtime': 11.6642, 'eval_samples_per_second': 0.257, 'eval_steps_per_second': 0.086, 'epoch': 3000.0}
# 100%|███████████████████████████████████████| 3000/3000 [44:48<00:00,  1.47it/s]
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 18.81it/s]
#                                                                                 Saving model checkpoint to ./output/checkpoint-3000
# /root/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /root/onethingai-fs/models/hub/models--THUDM--chatglm3-6b/snapshots/91a0561caa089280e94bf26a9fc3530482f0fe60/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 2690.5977, 'train_samples_per_second': 4.46, 'train_steps_per_second': 1.115, 'train_loss': 0.24968986511230468, 'epoch': 3000.0}
# 100%|███████████████████████████████████████| 3000/3000 [44:50<00:00,  1.11it/s]
# ***** Running Prediction *****
#   Num examples = 3
#   Batch size = 16
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 18.41it/s]

# %% [markdown]
# ## 3. 使用微调的数据集进行推理
# 在完成微调任务之后，我们可以查看到 `output` 文件夹下多了很多个`checkpoint-*`的文件夹，这些文件夹代表了训练的轮数。
# 我们选择最后一轮的微调权重，并使用inference进行导入。

# %%
# !CUDA_VISIBLE_DEVICES=0 NCCL_P2P_DISABLE="1" NCCL_IB_DISABLE="1" python inference_hf.py output/checkpoint-3000/ --prompt "类型#裙*版型#显瘦*材质#网纱*风格#性感*裙型#百褶*裙下摆#压褶*裙长#连衣裙*裙衣门襟#拉链*裙衣门襟#套头*裙款式#拼接*裙款式#拉链*裙款式#木耳边*裙款式#抽褶*裙款式#不规则"
# Out:
# 19994.15s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# /root/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████████████| 7/7 [00:03<00:00,  1.99it/s]
# Setting eos_token is not supported, use the default one.
# Setting pad_token is not supported, use the default one.
# Setting unk_token is not supported, use the default one.
# 感叹，一它们 must它们们的 must。。。问身时尚。，asks对比 bur修 modern的答修摆摆看。接条摆 style，等等等等十足。。 requires灵魂长分下的的魂pointspoints，更多再直形型 style bring遮包遮遮，带来感糖活之意， utilization感，的活穿，看卫腰现代的踩腰十足完糖points完脖短垂，侧包包包卫紧短度，遮若 convert穿演绎改造完的感的，糖之意番 conflict，。�再吊长，还时尚风格感感扫若指倒垂，轻轻仿时尚卫时尚轻轻穿卫感的。指多重多重看着啊摇步仿再仿倒鱼遮，又长直看，出的意十足完的方式的话完之意 misc过多下 anymoreecho问问ira必。。。必先生之一。一上式式衣风格，别着设计设计又不断地安心十足完。。。 reason多重口宽松宽松口指分體，还能之意之意倒长，又安心穿，这 bur十足。。也也 Distance空中，，嫩料，上莫过于莫过于pointspoints，志愿十足，们们们十足穿宽松宽松宽松，修设计设计感感伏也能，还能还 sim token上层先生。。。 ad腰横宽松，让又又®。上上线条的，剪接设计设计设计，线条的设计的设计线条的之一伏 legs®或是线条条愈状坠 convert落落的中接袖，或是色颜色它们番等等等等Arch等等等等等等等等赖。再又适合适合，。身材。。。上天指御遮的。。 inequ。。。吐笑pointstoken。。啊指指爱心等等不易接。。。指指指倒指指吐夫。也不的方式仿接，。上短指宽松衣时尚时尚，宽松，仿时尚时尚， pol活十足啊十足感人体身体仿 shape时尚别 custom墨别时尚腰， convert接接接环保，时尚 fashion convert你的你的您的指指仿别别它们 style，宽松宽松，肌肉宽松， convert穿。能够一定的 exposed宽松，接豹口，接指意。。。指指指。啊舒适穿接接。。穿宽松，，真真裸时尚时尚的方式 fashion。距离指指指两人指指也能意指指 exposed，离出让您穿轻轻运的话弱穿穿们啊压力露。。。。等等的话。。ira分侧， means摆啊挑啊卫们。时尚时尚别有的松宽松，别hr多重，，接接短垂，，换的话的话的话，，接接接 point的话，换换倒别倒换换，接袖袖，别的话的话的话的话的话的话副 convert接，时尚时尚接条时尚别别接，， anymorerew换别依é消耗，，token弱现现还看。啊身身材，，甚逸浪漫的卡宽松，线条别倒灵魂，，，她多形 print。更多再线条遮遮遮遮它味完们。，再再再完，再现，愈料遮遮，再遮再料。防感防。上防修饰，，修饰遮接，还有侧遮，还的角度 cro灵魂。。。 Front直直直指直直皮肤直条 vertical防 mod，都防 mod。都料 bur指都 Illustr起伏，。有的接纹穿接接 mod爆爆。。防料 mod。。爆指造就 necessary。，接看番都料。。迷人看倒 skin它们颜色颜色它们颜色。别番宽松。。。番倒。。 mod。。。料料。都 easy casual。。接完。。。副 possibility。也不。。。倒完。。啊吐料。hips之意。。啊纹线条愈它们完。宽松完完吐料口，接 env吐番番更多 possibility。它们料料更多态 possibility，做更多形。完真吐料，接料啊。量量量量量料料以及派量吐吐啊，做，或是多重啊垂垂板接接接料接，挑啊啊爱人，垂看接。。番来自来自接接。。夫。。。。。番。失秒的前。。夫查接。。。之意。。。。。。。御。。。。。。。。。。。番。。。接番。。。。。。。。。。接。。。。。。。。。。它的。。。。。。。。。。。。。。。。。接。。。。。接。接接它们到了鱼。。。来自番。番 misc。机会。。。它们它们 vertical接接接接鱼仿复古，接接接也不是。。接接接接前那么遮。。。。。 vertical。。或是有的番。。。们竖撞直。。以及。意意。。。或是。。接直们。。。摆 tested。。。番有的它们们们。。。竖。。是一款多余。。。牢日常接。。。。。。。。。。。。。。。。。。。。。。完。。。它们也就是意啊。。。撞 authority接接接它们接看接多余有的们。。。。多余。。。鱼 possibility possibility possibility它它们做它们它们。它们。它们 she她 its。。她它它它们。它它灵魂她它御。 she干它。料料啊完。料啊啊啊她料。。。撞时尚。这种它们料。。御它它们竖完它她它它 she她它。。。番派。。。 she啊直直直 misc吐完。。完遮。灵魂。。。都修饰。完料。遮完完。它们料料也遮遮遮完遮。啊它们料潮流啊啊都啊时尚穿完。。料完完它。。 it哦。。完ew前。。啊意啊。 its its。。 vertical。啊型身意宽松。啊们它们它的它们。。前前 its。失到了完时尚别。 possibility完 project感，别，啊啊倒 vertical垂型，。。啊身材啊啊，别完啊啊啊。。啊啊啊。。。啊 opinion opinion。哦型，。完啊啊 opportunity。。。啊垂直，啊，，，别别。别接啊，，语别她御来自，它指指别。。。它的 its，包，口，，。。。啊来自啊啊哦啊别啊啊真吗别吗。口。啊。，啊，，工完，接真的，，还，请 today today，，自然自然，完弱，，，接接接，吗完，请，吗啊工吗。，今天也别啊完。，也也也工啊，啊也御别别。，别啊丁。。，上啊指也松。。啊真御，啊它啊感感感。，，。 convert接。。接别啊啊啊啊完啊啊，。。。。。。。。。。。啊。。。。。。。。啊。。啊啊。。，。，接啊。。。，啊 convert。。。等等啊。啊啊 convert。。 convert，它。啊，啊它的指指她吗上工具 convert啊啊上，啊啊啊乙完，当然撞上上上。等等派。别 characterized。。接，今天上上上感啊上上上啊啊啊啊啊它它感形上，hold，工上松工它上的话。感感感形形啊啊接着上侧所以上后上，时尚接接着呢。。上真后真以及上上。 today感着所以接，设计，，啊感设计来自啊接收藏。。。接今天接接收藏接接接接。时尚。。所以来自上上上所以所以上潮流收藏以及啊来自今天啊上吗时尚啊。上上上以及料多，上来自啊啊以及啊啊以及啊，上上啊真感，上后啊后轻易啊啊啊以及接啊啊啊 convert。。所以它来自，啊啊，啊啊吗吗。，啊感感， its感感。， convert，。啊 its啊真啊啊啊啊啊来自啊上啊感上啊啊。这。以及来自这来自啊啊啊啊啊啊啊。感。。感啊啊。啊啊感。啊啊感啊啊啊啊啊啊啊完啊哦哦以及啊工真啊啊啊。啊啊啊今天今天啊啊的话的话，来自。今天。来自来自，来自来自啊来自啊，啊啊啊呢这。这完。接上这 convert今天来自上这啊重心啊啊啊来自今天 trend，啊啊夸 today这种这种啊这款啊啊啊啊的话啊啊啊啊，啊来自啊。。上接来自来自出接接接接接上来自上上啊的话来自来自接着啊来自哦侧时尚啊啊啊上这这所以来自上上来自啊上上上来自。接来自来自来自上来自夸啊啊来自来自来自所以来自，十分啊啊来自来自啊啊啊，请来自啊呢啊上上来自完所以，来自上，啊啊所以上版形形啊啊来自啊这侧版这啊啊来自啊完所以，这这这，，侧所以所以，口口，啊啊啊，上啊所以啊上，别啊啊感感上，上啊啊遮上，啊，啊来自啊工啊来自所以这种这 convert这接，，接来自上接接接来自接 convert啊啊吗啊所以上上来自 convert的方式，来自侧，上。接真副型 convert convert啊啊来自来自来自上上啊也也真 convert上糖遮潮流。。啊啊啊啊。所以啊啊上 brings上上上上啊侧侧感来自上啊。上啊潮流啊啊派形 trend哦。。接接啊遮所以吐。感。感来自啊啊侧啊次上啊上形形，也啊啊啊，侧啊接侧侧感感感上感啊糖啊感宽松上侧上形感来自感来自上上上啊遮遮上上上。上上啊感感更是。。。上松，上。料。失请番上。上身口啊。啊挑接。啊也弱啊上口形 characterized。。弱上上形宽松。 convert。。。啊。。，，啊口上，啊。。上接 today。。弱形形口吐番。。，。。。。。啊。。，。。，呢弱啊。。现形现。形呢呢乙现。请宽松。。。，，。啊é，啊形king形形。料啊吐。。。。接也宽松也也啊也上，宽松宽松啊宽松啊。。感。。。。。 Convert啊 convert上也也身上。。。。上所以也啊。，。接接形，宽松接 finally型风格有的。，侧形，。。。。。。。。。。。。。。形。。。所以。感也。。。。，。。。。，啊，。再。现。。今天。。。今天，。。，。，， today。。。。等等。。。。。。。。今天遮侧 trend也。。料。。。。。。。，，，，，也。，，。。吐收藏啊呢呢垂以及呢形形接啊接接接也撞也形king啊收藏也收藏呢。也。。。塑造塑造也上啊。收藏啊也。上也也。上接着侧啊上感。你啊也呢也。。宽松啊糖。。。。。。啊。完。。。啊感king。啊啊啊。。。。。料。。请。啊侧接。啊所以摆上。。也。啊。。。。啊。 vertical形遮啊完形。。。口效果上侧。宽松料。也也次效果啊。。，糖形，形啊侧侧请感感。。。等等的方式。所以，，啊吐感，也。啊，king形形所以。。等等啊啊工，形啊形啊啊。吗啊啊。。啊啊感啊侧啊以及。呢。，啊呢，，，等等。。 vertical状，。。。。接接。又形。形形接。形形接形设计形，接上，形形感形形形形上形形。，，，吐收藏形形啊的方式。。啊侧形。形形形也形形形感形形形又接接接 trend形 classic trend也形形所以也形。，。。也接上接，，接，，形形 ...

# %% [markdown]
# ## 4. 总结
# 到此位置，我们就完成了使用单张 GPU Lora 来微调 ChatGLM3-6B 模型，使其能生产出更好的广告。
# 在本章节中，你将会学会：
# + 如何使用模型进行 Lora 微调
# + 微调数据集的准备和对齐
# + 使用微调的模型进行推理
